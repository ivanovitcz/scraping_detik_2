# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import re
import pandas as pd

# %%
#cek paginasi, hanya ambil 2 page, karena pada beberapa kategori berita di Detik tidak ada pagination nya 

def check_pagination(jenis, date):
    all_url = []
    for i in range(1,3):
        check_url = 0
        url_by_page = "https://{}.detik.com/indeks/{}?date={}".format(jenis,i,date)
        url_c = uReq(url_by_page)
        html_page = url_c.read()
        url_c.close()
        page_html_soup = soup(html_page, "html.parser")
        check_content = page_html_soup.select("ul li article")
      
        if(len(check_content) != 0):
            all_url.append(url_by_page)
        
    return all_url

# %%
#scraping content pada satu page

def one_page_content(container):   
    berita = []

    for article in container:
        temp_list = []

        url = article.select("a")[0].attrs["href"]
        title = article.select("h2")[0].text

        url_content  = uReq(url+"?single=1")
        try:
            html_content = url_content.read()
        except SocketError as e:
            if e.errno != errno.ECONNRESET:
                raise 
            pass
        url_content.close()
        
        content_soup = soup(html_content, "html.parser")
        container_content = content_soup.findAll("p")  
        
        content = ""
        print(title)
        if(len(container_content) == 0):
            content = content_soup.findAll("div",{"class":"detail_text"})
            content = content[0].text
            content = content.replace("\n","")
            content = content.replace("\t","")
        else:
            for i in container_content:
                content = content + " " + i.text

        temp_list.extend([url,title,content])

        berita.append(temp_list)
        
    berita = pd.DataFrame(berita, columns = ['url','title','content'])        
    return berita

# %%
#melakukan scraping pada tanggal spesifik
#sesuaikan bulan date, format mm/dd/yyyy
#sesuaikan jenis kategori berita yang diinginkan

def semua(tanggal):
    #sesuaikan date, format mm/dd/yyyy
    date = "10/"+str(tanggal)+"/2020"
    #jenis berita Detik (news, finance, hot)
    jenis = "oto"


    df = pd.DataFrame([], columns=['url','title','content'])
    pagination = check_pagination(jenis, date)
    print("total page "+str(len(pagination)))

    count = 0
    for i in pagination:
        count += 1
        print("page", count)
        page_url = uReq(i)
        html_page = page_url.read()
        page_url.close()
        html_soup_page = soup(html_page, "html.parser")
        container_page = html_soup_page.select("ul li article div.desc_idx")
        berita = one_page_content(container_page)
        df = df.append(berita, ignore_index=True)
    
    return df

# %%
#looping pada range tanggal tertentu
#sesuaikan bulan date, format mm/dd/yyyy
#sesuaikan jenis kategori berita yang diinginkan

for i in range(16,20):
    print("+++++++++==========MULAI TANGGAL "+str(i)+"=============================")    
    result = semua(i)
    columns = result.columns.values
    print()
    for j in columns:
        missing = (result[j].isnull().sum()/result.shape[0])*100
        print('Percent of missing '+j+' records is %.2f%%' %(missing))
    print()
    jenis_result = "oto"
    date_result = "10/"+str(i)+"/2020"
    date_format = date_result.split("/")
    result.to_csv("detik-"+jenis_result+"-"+date_format[1]+"-"+date_format[0]+"-"+date_format[2]+".csv")
    print("+++++++++==========DONE TANGGAL "+str(i)+"=============================")
# Out:
# +++++++++==========MULAI TANGGAL 16=============================
# total page 2
# page 1
# Tim MotoGP Indonesia Akan Launching di Hari Sumpah Pemuda 28 Oktober
# Hasil Latihan Bebas II MotoGP Aragon: Yamaha Masih Dominan, Vinales Kembali Tercepat
# Honda Protes: Jangan Anak Emaskan Mobil Listrik, Ada Jenis Hybrid Juga
# Mercedes Ikut Jejak Honda Tinggalkan F1?
# Dipecat Jadi Gubernur Aceh, Intip Garasi Irwandi Yusuf dari Mobil Mewah Hingga Pesawat
# Brak! Mobil PJR Polisi Ringsek Ditabrak Truk Rem Blong
# Penjualan Mobil Naik, Ini Merek Terlaris
# Perbaiki Mobil Rusak Imbas Demo Bisa Diklaim Asuransi, Asal...
# Hasil Latihan Bebas I MotoGP Aragon: Trio Yamaha Tercepat, Alex Marquez Unjuk Gigi
# Anies 3 Tahun Pimpin DKI: Kontroversi Formula E Hingga Sepeda Masuk Tol
# Sudah Sampai Mana Persiapan Tim Balap Indonesia di MotoGP 2021?
# Motor Pakai Pelat 'Dilarang Merokok', Mau Ngelucu Malah Kena Tilang
# Penampakan Kondisi Jalan di Kuala Lumpur yang Kembali Lockdown
# 3 Tahun Anies di DKI: Pajak Mobil Listrik Gratis sampai Wajib Uji Emisi Motor-Mobil
# Yang Beda dari Kontes Daihatsu Dressup Challenge 2020
# Kasus COVID-19 Masih Banyak, Penjualan Mobil Tetap Nanjak, Kok Bisa?
# Ngarep Pajak 0%? LCGC Batal Turun di Bawah Rp 100 Juta, Segini Harganya Sekarang
# Industri Otomotif Indonesia: Lebih Baik Kesehatan daripada Pajak Mobil Baru 0%
# Kakek-kakek Abang Jago! Garuk Punggung Pakai Excavator
# Makin Macho, Ini Penampakan Toyota Fortuner Terbaru
# page 2
# Pasar Otomotif Bergantung pada Vaksin COVID-19
# Lihat Dari Dekat Wajah Toyota New Kijang Innova
# Pajak 0% Masih di Awang-awang, Ini Harga Toyota Rush-Mitsubishi Xpander Cs Sekarang
# Rossi yang Malang di 2020: Didepak Yamaha, Nyaris Mati, Crash Terus, Kini Kena Corona
# Toyota New Fortuner Harganya Tembus Rp 700 Juta, Siapa yang Mau Beli?
# Pimpinan KPK Akan Dapat Mobil Dinas Rp 1,4 M, Mobil Apa Saja yang Cocok?
# Berkendara di Dekat Truk? Segera Menjauh, Anda Dalam Bahaya!
# Sigra dan Gran Max jadi Jagoan Daihatsu di Tengah Pandemi
# Pajak Mobil Baru 0% Ditunggu Tak Datang, Penjualan Daihatsu Tetap Moncer
#
# Percent of missing url records is 0.00%
# Percent of missing title records is 0.00%
# Percent of missing content records is 0.00%
#
# +++++++++==========DONE TANGGAL 16=============================
# +++++++++==========MULAI TANGGAL 17=============================
# total page 2
# page 1
# Hasil Kualifikasi MotoGP Aragon: Quartaro Pole Position Setelah Jatuh Saat Latihan
# Jatuh Saat Latihan, Bagaimana Kondisi Fabio Quartararo Saat Ini?
# Bus Mewah Trans Jawa Rute Malang-Jakarta, Penumpang Duduk Sendiri-sendiri
# Hasil Latihan Bebas III MotoGP Aragon: Yamaha Masih yang Tercepat
# Bandung Auto Fest 2.0 Ajang Modifikasi Warga Bandung
# Modifikasi Kabin Mobil Jadi Kantor Mewah, Asyik Juga Ya
# Di Perempatan Jalan Raya Ada Garis Kotak Berwarna Kuning, Jangan Bingung Ini perannya
# Lapisan Kaca Helm Quartararo yang Bikin Motor Miller Ngempos Terjual Rp 81 Juta
# Yamaha Vinoora si Lucu yang Punya Mata Belo
# Ada yang Tahu Arti Garis Putih, Kuning, Cokelat, Hijau dan Merah di Jalan Raya?
# Tim MotoGP Indonesia Tak Cuma Turun di MotoGP Mandalika, Bakal Ikut Full Season
# Meski Online, Pameran Modifikasi di Indonesia Berhasil Sedot 27.658 Penonton
# Ayo Tebak, Berapa Tahun Sekali Marka Jalan Dipermak para Petugas?
# New Kijang Innova Disebut Minim Inovasi, Ini Komentar Toyota
# 9 Juta Seatbelt Takata Tak Sesuai Standar
# Jangan Cuek! Ini Pentingnya Marka Jalan Bagi Anda Seorang Pengendara
# Separuh Tim MotoGP Indonesia Akan Diisi Orang Asing, Termasuk Pebalap
# Mumpung Libur Cuci Mobil ala Profesional Yuk...
# Sejarah Bicara, Logo Ferrari Awalnya untuk Alfa Romeo
# Yamaha Vinoora: Skutik Yamaha Berdesain Lucu yang Punya Mata Belo
# page 2
# Tim MotoGP Indonesia Bakal Dapat Dukungan dari Pertamina dan Garuda
# Masih Perlukah Motor Injeksi Geber-geber Panaskan Mesin Sebelum Jalan?
# Sejarah Logo Ferrari: Kenapa Pilih Gambar Kuda Jingkrak?
#
# Percent of missing url records is 0.00%
# Percent of missing title records is 0.00%
# Percent of missing content records is 0.00%
#
# +++++++++==========DONE TANGGAL 17=============================
# +++++++++==========MULAI TANGGAL 18=============================
# total page 1
# page 1
# Hasil MotoGP Aragon 2020: Alex Rins Juara, Marquez Podium Lagi, Quartararo Tercecer
# Strategi Suzuki Kenalkan Produk Baru di Masa Pandemi, Berhasil!
# Toyota Mirai Jadi Mobil Baru Paus Fransiskus
# Pabrik Pembuat iPhone Sekarang Bikin Mobil Listrik
# Link Live Streaming MotoGP Aragon di Trans7 dan detikOto, Tonton di Sini!
# Adik-Abang Espargaro Tabrakan, Gara-gara Alex Marquez?
# Ngeri! Bahaya Penumpang Kursi Belakang yang Tak Pakai Sabuk Pengaman
# Potret Mobil Bongsor Mercy yang Disulap Jadi Kantor Berjalan
# Euisun Chung Jadi Bos Baru Hyundai
# Baterai Bisa Picu Kebakaran, Puluhan Ribu Mobil Listrik BMW Ditarik
# Belajar dari Kecelakaan Beruntun di Tol Cipali yang Dialami Hanafi Rais
# Dovizioso Ngamuk sampai Lempar Sarung Tangan, Ini Sebabnya
# Ribut Gegara 15 Mobil Parkir Depan Rumah, Gimana Aturannya?
# Morbidelli Kaget Rossi Positif COVID-19, Padahal Patuh Protokol Kesehatan
# Jadwal Live Streaming MotoGP Aragon, Simak di Sini
# Mau Kredit New Kijang Innova dan New Fortuner? Ini Skema Cicilannya
# Lokasi Layanan SIM Keliling di Jakarta Hari Ini
# Naik Bus Mewah Trans Jawa Rute Malang-Jakarta, Segini Tarifnya
# Wow! Umur CR-V Sudah Seperempat Abad, Tahun Depan Makin Irit BBM
# Suara Audio Mobil Hilang? Ini 5 Penyebabnya
#
# Percent of missing url records is 0.00%
# Percent of missing title records is 0.00%
# Percent of missing content records is 0.00%
#
# +++++++++==========DONE TANGGAL 18=============================
# +++++++++==========MULAI TANGGAL 19=============================
# total page 2
# page 1
# Zero Motorcycles Umumkan Pembaruan Line Up Motor Listrik 2021
# Alexandra Perez, Si Manis Tunangan Alex Rins
# Nah Lho! Valentino Rossi Positif Corona Gegara Hadiri Pesta Ultah Pacarnya?
# Tahun 2020 Hampir Usai, Honda Nggak Punya Mobil Baru di Indonesia?
# Sri Mulyani Tolak Pajak Mobil Baru 0%, Begini Respons Honda
# Nyetir Sambil Main HP di Inggris Didenda Rp 3,8 Juta, di RI Cuma Rp 750 Ribu
# Awas! Langgar Marka Jalan Juga Bisa Kena Tilang Elektronik
# Komentar Kocak Alex Rins soal Marquez: Kakaknya Enggak Ada, Eh Nongol Adiknya
# Mimpi Indah Pajak Mobil Baru 0%.... yang Kini Cuma Jadi PHP
# Mobil Misterius Mirip Daihatsu Rocky Kedapatan Tes Jalan di Indonesia
# Daftar 20 Mobil Terlaris September 2020, Tanpa Pajak 0%
# Mobil Bekas Tesla Sudah Ada yang Jual? Berapa Harganya?
# Pajak Mobil Baru 0 % Ditolak, Pedagang Mobil Bekas yang Girang
# Tenggelam di MotoGP, Kawasaki Sabet 6 Gelar Juara WSBK Beruntun
# Curhat Vinales Motornya Tak Bisa Bendung Alex Rins di MotoGP Aragon
# Pajak Mobil Baru 0 Persen Ditolak, Segini Harga Innova dkk Sekarang
# Maaf! Tak Ada Pajak Mobil Baru 0%
# Kabar dari Yamaha Aerox Terbaru, Bakal Dapat Fitur Seperti New Nmax?
# Kemenperin Bicara Relaksasi Pajak Mobil, Diharap Tingkatkan Industri Otomotif
# Marc Marquez Komat-kamit Terus, Nonton Adiknya di MotoGP Aragon
# page 2
# Quartararo Tercecer Gegara Ban, Berapa Tekanan Angin Ban Ideal di Motor MotoGP?
# Begini Update Kondisi Valentino Rossi 3 Hari Usai Positif Corona
# Berkat Marc, Ini yang Bikin Alex Marquez Mulai Kompetitif di MotoGP
# Cuek dengan Marka Jalan, Siap-siap Rp 500 Ribu Melayang
# Gegara Tekanan Angin Ban Depan, Quartararo Tercecer ke Belakang di MotoGP Aragon
# Meme Lucu Marc, Eh Alex Marquez Naik Podium MotoGP Aragon
# 3 Cara Lindungi Kendaraan dari Risiko Kerusuhan Massa
# Catat! Ini Lokasi Perbaikan Jalan di Tol Jagorawi dan Jakarta-Cikampek
# Bentuk-bentuk Marka Jalan yang Ada di Indonesia Berserta Artinya
# Klasemen MotoGP Usai Balapan Aragon: Pssttt...Alex Marquez Sudah di Atas Rossi
# Melihat Lebih Dekat Toyota Mirai Mobil Baru Paus Fransiskus
#
# Percent of missing url records is 0.00%
# Percent of missing title records is 0.00%
# Percent of missing content records is 0.00%
#
# +++++++++==========DONE TANGGAL 19=============================
